# %%
import requests
from bs4 import BeautifulSoup
import json

# Define the subreddit and the URL
subreddit = 'sentimentanalysis'  # Change this to any subreddit you're interested in
base_url = f'https://www.reddit.com/r/{subreddit}/top/.json?limit=10'  # Fetch top 10 posts

# Define headers to avoid blocking by Reddit
headers = {'User-Agent': 'Mozilla/5.0'}

# Function to scrape posts from Reddit
def scrape_reddit_posts(url):
    posts = []
    after = None

    # Loop to handle pagination
    for _ in range(3):  # Adjust the number of pages you want to scrape
        params = {'after': after} if after else {}
        
        # Send GET request to fetch data
        response = requests.get(url, headers=headers, params=params)
        
        # If request is successful, process the JSON data
        if response.status_code == 200:
            data = response.json()
            post_data = data['data']['children']
            
            # Extract relevant post details
            for post in post_data:
                title = post['data']['title']
                upvotes = post['data']['ups']
                comments = post['data']['num_comments']
                posts.append({'title': title, 'upvotes': upvotes, 'comments': comments})
            
            # Set the "after" parameter to fetch the next page
            after = data['data']['after']
        else:
            print(f"Failed to retrieve data: {response.status_code}")
            break
        
    return posts

# Function to display collected posts
def display_posts(posts):
    for post in posts:
        print(f"Title: {post['title']}")
        print(f"Upvotes: {post['upvotes']}, Comments: {post['comments']}")
        print("="*80)

# Main function to execute the scraping
if __name__ == "__main__":
    # Start scraping
    print("Scraping Reddit posts...")
    posts = scrape_reddit_posts(base_url)
    
    # Display the collected posts
    display_posts(posts)
# Out:
# Scraping Reddit posts...
# Title: Discover the Economic Highs and Potential Risk Ahead: Economic and Market Review
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Discover the Economic Highs and Potential Risk Ahead: Economic and Market Review
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Discover the Economic Highs and Potential Risk Ahead: Economic and Market Review
# Upvotes: 1, Comments: 0
# ================================================================================

# %%
import requests
import json

# Define the subreddit and the base URL
subreddit = 'sentimentanalysis'  # Change this to any subreddit you're interested in
base_url = f'https://www.reddit.com/r/{subreddit}/new/.json?limit=25'  # Fetch 25 posts, sorted by "new"

# Define headers to avoid blocking by Reddit
headers = {'User-Agent': 'Mozilla/5.0'}

# Function to scrape posts from Reddit
def scrape_reddit_posts(url):
    posts = []
    after = None
    page_count = 0  # To keep track of how many pages we have scraped
    
    # Loop to handle pagination
    while True:
        params = {'after': after} if after else {}
        
        # Send GET request to fetch data
        response = requests.get(url, headers=headers, params=params)
        
        # If request is successful, process the JSON data
        if response.status_code == 200:
            data = response.json()
            post_data = data['data']['children']
            print(f"Page {page_count + 1} fetched. Found {len(post_data)} posts.")  # Debug output
            
            # Extract relevant post details
            for post in post_data:
                title = post['data']['title']
                upvotes = post['data']['ups']
                comments = post['data']['num_comments']
                posts.append({'title': title, 'upvotes': upvotes, 'comments': comments})
            
            # Set the "after" parameter to fetch the next page
            after = data['data']['after']
            
            # Stop if there are no more pages to scrape
            if not after:
                print("No more pages to scrape.")
                break
            page_count += 1
        else:
            print(f"Failed to retrieve data: {response.status_code}")
            break
        
    return posts

# Function to display collected posts
def display_posts(posts):
    if posts:
        for post in posts:
            print(f"Title: {post['title']}")
            print(f"Upvotes: {post['upvotes']}, Comments: {post['comments']}")
            print("="*80)
    else:
        print("No posts found.")

# Main function to execute the scraping
if __name__ == "__main__":
    # Start scraping
    print("Scraping Reddit posts...")
    posts = scrape_reddit_posts(base_url)
    
    # Display the collected posts
    display_posts(posts)
# Out:
# Scraping Reddit posts...
# Page 1 fetched. Found 25 posts.
# Page 2 fetched. Found 25 posts.
# Page 3 fetched. Found 25 posts.
# Page 4 fetched. Found 25 posts.
# Page 5 fetched. Found 5 posts.
# No more pages to scrape.
# Title: Discover the Economic Highs and Potential Risk Ahead: Economic and Market Review
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Navigating the Sentiment Analysis Jungle: Comparing Automated Tools
# Upvotes: 6, Comments: 4
# ================================================================================
# Title: Anyone know any firms in India or Bangalore that I could utilise for social media management?
# Upvotes: 1, Comments: 2
# ================================================================================
# Title: What manual sentiment Analysis looks like
# Upvotes: 4, Comments: 2
# ================================================================================
# Title: remote job opportunity
# Upvotes: 1, Comments: 7
# ================================================================================
# Title: Websites that do not consider web scraping illegal?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Websites that do not consider web scraping illegal?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Survey for Sentiment Analysis Project
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: MonkeyLearn Sentiment Analyzer Sign Up issue
# Upvotes: 6, Comments: 5
# ================================================================================
# Title: Sentiment Analysis Issue
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Best way to analyze 100's survey responses from cyclists
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: [OC] Sentiment on "Inflation" is going more and more positive. The line below is drawn based on a sentiment analysis of 3,062,073 financial news articles. What impacts will this have...
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Sentiment analysis as a currency prediction tool
# Upvotes: 3, Comments: 4
# ================================================================================
# Title: Automating Sentiment Analysis in WhatsApp with Automation Anywhere AA360: Simple Integration | GenAI OpenAI GPT
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Thoroughly stumped in my research question goals
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: [OC] Sentiment on the "NASDAQ" narrative (yellow). NASDAQ 100 price (blue). Narrative line based on 1,137,532 financial news articles. Source: https://tradervoice.io
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Is sentiment analysis useful?
# Upvotes: 2, Comments: 4
# ================================================================================
# Title: what is the best tool for sentiment analysis on twitter?
# Upvotes: 2, Comments: 4
# ================================================================================
# Title: Individuals with an interest in the equity markets; Current investment in the stock market not mandatory; simply stock market knowledge
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: The impact of narratives on financial markets
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Sentiment at an individual voice interaction level
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Helping a School Proyect
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Which pre-trained model should I choose for sentiment analysis on Reddit comments?
# Upvotes: 1, Comments: 2
# ================================================================================
# Title: What are the best tools for amazon product reviews sentiment analysis
# Upvotes: 2, Comments: 5
# ================================================================================
# Title: Different approaches / reviews on sentiment analysis?
# Upvotes: 3, Comments: 1
# ================================================================================
# Title: Looking for Sentiment Analysis 3rd Party Solution NodeJS/Python
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Text Generation using Sentiment Analysis
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Aggregate sentiment analysis on journalists
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Help with Sentiment Analysis Python
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: My work over a couple of years on UFC Sentiment Analysis
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Need Help with Comparative Study of Lexicons
# Upvotes: 2, Comments: 3
# ================================================================================
# Title: How can i analyse sentiments on social media and what are the best tools for that?
# Upvotes: 2, Comments: 3
# ================================================================================
# Title: Hello all! Testing the waters here looking for more of a crowd sourced answer
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: Please recommend some SA tools
# Upvotes: 2, Comments: 5
# ================================================================================
# Title: What exactly is consumer sentiment analysis, and why does it matter?
# Upvotes: 1, Comments: 3
# ================================================================================
# Title: Hi Everyone. We’re in the process of labeling some student’s comments in order to build a corpus for student sentiment analysis. If you have some free time, please visit the below link. Thanks in advance for your cooperation.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: What is the primary goal of sentiment analysis on social sites?
# Upvotes: 2, Comments: 3
# ================================================================================
# Title: Need help with a sentiment analysis project
# Upvotes: 2, Comments: 1
# ================================================================================
# Title: Looking for Enterprise IT Service Dataset
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Sentiment Analysis survey
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: By popular demand: a deep-dive analysis of media sentiment surrounding bitcoin over the past 90 days (3/25-6/23),
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Hello and Happy to be here
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Need some suggestions with sentiment analysis tools
# Upvotes: 3, Comments: 3
# ================================================================================
# Title: What Type of Sentiment Analysis Can you measure with Newsdata.io API?
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: suggestion for a text-based depression detection system
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Seeking participants for a research study on the text analysis of a meaningful memory of a day since the onset of COVID-19
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: News articles, and social media sentiment analysis
# Upvotes: 2, Comments: 3
# ================================================================================
# Title: Does anyone know a free good program?
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: [OC] Difference between Azure and AWS ML on same dataset
# Upvotes: 2, Comments: 1
# ================================================================================
# Title: Dataset
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: Sentiment Analysis Catching Fall or Rise in Stock Prices
# Upvotes: 1, Comments: 2
# ================================================================================
# Title: Sentiment Analysis Catching Fall or Rise in Stock Prices
# Upvotes: 6, Comments: 0
# ================================================================================
# Title: New Analysis from Falcon.io Highlights Social Media Trends Around the U.S. Presidential Election
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: I want to convert time from time stamp to nearest hour in Python. Can anyone help?
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: NRC Lexicon
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: tomomunoz - Sentiment / Emotion Analysis
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Sentiment Analysis on Tweets/RTs for Joe Biden and Donald Trump
# Upvotes: 4, Comments: 3
# ================================================================================
# Title: O365 sentiment analysis
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Intuition of how to do sentiment analysis ?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: I need Dataset from twitter, help.
# Upvotes: 2, Comments: 6
# ================================================================================
# Title: COVID-19, altruism and the Tiger King - What does Twitter sentiment reveal about how the UK is reacting to the Coronavirus pandemic?
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Adjectives that negate
# Upvotes: 2, Comments: 2
# ================================================================================
# Title: Neutrals in sentiment analysis
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: The result section of my sentiment analysis study is too empty.
# Upvotes: 1, Comments: 2
# ================================================================================
# Title: Where should be the quotes from social media? In Results or Discussion?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Greek Sentiment Analysis
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: How many sentences are enough for sentiment analysis or content analysis?
# Upvotes: 1, Comments: 3
# ================================================================================
# Title: I’m looking for a sentiment analysis that can handle sentences like this one “I had to wait a long time to be seated but the burger was good.”
# Upvotes: 2, Comments: 2
# ================================================================================
# Title: CryptoMood from idea to a powerful tool for market sentiment analysis.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: How Understanding Social Media Sentiment Can Help Your Trades
# Upvotes: 1, Comments: 1
# ================================================================================
# Title: Why Sentiment Is So Important For Trading
# Upvotes: 1, Comments: 1
# ================================================================================
# Title: Sentiment Analysis with Python
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: UNDERSTANDING SENTIMENT ANALYSIS API
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: what are AI frontiers applications of Sentiment Analysis ?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Best papers to get started with research on Cross-lingual sentiment analysis
# Upvotes: 3, Comments: 4
# ================================================================================
# Title: Voice sentiment analysis
# Upvotes: 4, Comments: 0
# ================================================================================
# Title: Examples for introduction
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Round 2 is much improved over round 1, including using 2 sentiment analysis libraries simultaneously (TextBlob and Vader) to improve accuracy.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: I mostly want to use VADER for its name, but has anyone actually used it?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: I finally got Twitter Sentiment Analysis to work, but only 10 tweets were analyzed. Does anyone know how to pull more than 10 tweets at a time out of tweepy: public_tweets = api.search('chocolate') for tweet in public_tweets:
# Upvotes: 1, Comments: 6
# ================================================================================
# Title: I'm looking forward to applying Sentiment Analysis to community service, helping volunteer groups better determine the needs of their communities.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Sentiment analysis and confusion about dataset, methods and tools
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Where is data located?
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Any service for sentiment analysis in Arabic? And is it a nice idea to use google translate on an Arabic sentence to translate to English and then run sentiment analysis on the English sentence?
# Upvotes: 1, Comments: 1
# ================================================================================
# Title: Do you know any sentiment analysis tool for China? (comparable to e.g. sentione)
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: SentimentDesk Free Beta
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: All the Feels: Sentiment Analysis A brief intro.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Multilingual sentiment analysis demo
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: Final Paper about Sentiment Analysis Help
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Twitter Sentiment Analysis with Postman
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: I used Sentiment Analysis to determine if Trump is melting down
# Upvotes: 3, Comments: 1
# ================================================================================
# Title: News Sentiment Analysis API
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Ways in Which Sentiment Analysis Can Help Improve Your Brand
# Upvotes: 2, Comments: 1
# ================================================================================
# Title: Life is too short, why not just live.
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Regarding Survey Paper
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: This is a noob question.
# Upvotes: 1, Comments: 1
# ================================================================================
# Title: Build your own sentiment analysis tool in 10 minutes with Google Sheets &amp; IFTTT. No coding required!
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Web Summit 2016 according to Twitter: Text mining 80,000 tweets. Sentiment analysis, entity &amp; concept extraction
# Upvotes: 3, Comments: 0
# ================================================================================
# Title: Sentiment Analysis for Mental Health
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Aspect-based sentiment analysis on hotel reviews in google sheets
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Let Me Hear Your Voice and I Will Tell You How You Feel
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Facial Emotion Recognition: Single-Rule 1–0 DeepLearning
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: Thoughts on Motivation and Self-Motivated Software
# Upvotes: 1, Comments: 0
# ================================================================================
# Title: David and Goliath, or I Trying to Beat Microsoft at Facial Emotion Detection
# Upvotes: 2, Comments: 0
# ================================================================================
# Title: Welcome!
# Upvotes: 1, Comments: 0
# ================================================================================

# %%
import requests
import csv

# Define the subreddit and the base URL
subreddit = 'sentimentanalysis'  # Change this to any subreddit you're interested in
base_url = f'https://www.reddit.com/r/{subreddit}/new/.json?limit=25'  # Fetch 25 posts, sorted by "new"

# Define headers to avoid blocking by Reddit
headers = {'User-Agent': 'Mozilla/5.0'}

# Function to scrape posts from Reddit
def scrape_reddit_posts(url):
    posts = []
    after = None
    page_count = 0  # To keep track of how many pages we have scraped
    
    # Loop to handle pagination
    while True:
        params = {'after': after} if after else {}
        
        # Send GET request to fetch data
        response = requests.get(url, headers=headers, params=params)
        
        # If request is successful, process the JSON data
        if response.status_code == 200:
            data = response.json()
            post_data = data['data']['children']
            print(f"Page {page_count + 1} fetched. Found {len(post_data)} posts.")  # Debug output
            
            # Extract relevant post details
            for post in post_data:
                title = post['data']['title']
                upvotes = post['data']['ups']
                comments = post['data']['num_comments']
                posts.append({'title': title, 'upvotes': upvotes, 'comments': comments})
            
            # Set the "after" parameter to fetch the next page
            after = data['data']['after']
            
            # Stop if there are no more pages to scrape
            if not after:
                print("No more pages to scrape.")
                break
            page_count += 1
        else:
            print(f"Failed to retrieve data: {response.status_code}")
            break
        
    return posts

# Function to save posts to CSV
def save_to_csv(posts, filename='reddit_posts.csv'):
    with open(filename, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['title', 'upvotes', 'comments'])
        writer.writeheader()
        writer.writerows(posts)
    print(f"Data saved to {filename}")

# Main function to execute the scraping
if __name__ == "__main__":
    # Start scraping
    print("Scraping Reddit posts...")
    posts = scrape_reddit_posts(base_url)
    
    # Save the posts to a CSV file
    save_to_csv(posts)
# Out:
# Scraping Reddit posts...
# Page 1 fetched. Found 25 posts.
# Page 2 fetched. Found 25 posts.
# Page 3 fetched. Found 25 posts.
# Page 4 fetched. Found 25 posts.
# Page 5 fetched. Found 5 posts.
# No more pages to scrape.
# Data saved to reddit_posts.csv
